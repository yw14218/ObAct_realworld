# %%
# Cell 1: Import Libraries
import h5py
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
from IPython.display import display, clear_output

# Cell 2: Define Helper Functions
def load_episode(file_path):
    """Load data from an HDF5 episode file."""
    with h5py.File(file_path, 'r') as f:
        rgb = np.array(f['/observations/images/rgb']) if '/observations/images/rgb' in f else None
        depth = np.array(f['/observations/images/depth']) if '/observations/images/depth' in f else None
        qpos_arm1 = np.array(f['/observations/qpos'])
        camera_pose_qpos = np.array(f['/camera_pose/qpos'])
    return rgb, depth, qpos_arm1, camera_pose_qpos

def plot_image(image, title="Image", cmap=None):
    """Plot an image using matplotlib."""
    plt.figure(figsize=(8, 6))
    plt.imshow(image, cmap=cmap)
    plt.title(title)
    plt.axis('off')
    plt.show()

def plot_joint_positions(qpos, title="Joint Positions"):
    """Plot joint positions as a line graph."""
    plt.figure(figsize=(10, 4))
    plt.plot(qpos, marker='o', linestyle='-', color='b')
    plt.title(title)
    plt.xlabel("Joint Index")
    plt.ylabel("Position (rad)")
    plt.grid(True)
    plt.show()

# Cell 3: Create MP4 from RGB Images
def create_rgb_video(dataset_dir, folder_name, output_video_path="output_rgb_video.mp4", fps=20):
    """Create an MP4 video from RGB images in all episodes."""
    episode_files = sorted([f for f in os.listdir(os.path.join(dataset_dir, folder_name)) 
                           if f.endswith('.h5')], key=lambda x: int(x.split('_')[1].split('.')[0]))
    
    if not episode_files:
        print("No HDF5 files found in the specified folder.")
        return
    
    # Load the first episode to get image dimensions
    first_file = os.path.join(dataset_dir, folder_name, episode_files[0])
    rgb, _, _, _ = load_episode(first_file)
    if rgb is None:
        print("No RGB data found in the first episode.")
        return
    
    height, width, _ = rgb.shape
    
    # Initialize video writer
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for MP4
    video_writer = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))
    
    # Process each episode
    for episode_file in episode_files:
        file_path = os.path.join(dataset_dir, folder_name, episode_file)
        rgb, _, _, _ = load_episode(file_path)
        
        if rgb is not None:
            # Convert BGR to RGB for display consistency (optional, remove if you want raw BGR)
            rgb_frame = cv2.cvtColor(rgb, cv2.COLOR_BGR2RGB)
            # Write frame to video
            video_writer.write(rgb_frame)
            print(f"Added frame from {episode_file}")
        else:
            print(f"Skipping {episode_file} - No RGB data found.")
    
    # Release the video writer
    video_writer.release()
    print(f"Video saved as {output_video_path}")

# Specify dataset directory and folder name
dataset_dir = "datasets"
folder_name = "20250324_203250"  # Replace with your timestamp
output_video_path = f"{dataset_dir}/{folder_name}/rgb_video.mp4"

# Create the video
create_rgb_video(dataset_dir, folder_name, output_video_path, fps=30)

# Cell 4: Load and Visualize a Single Episode (Optional)
episode_idx = 0
file_path = os.path.join(dataset_dir, folder_name, f"episode_{episode_idx}.h5")
rgb, depth, qpos_arm1, camera_pose_qpos = load_episode(file_path)

# if rgb is not None:
#     rgb_display = cv2.cvtColor(rgb, cv2.COLOR_BGR2RGB)
#     plot_image(rgb_display, title=f"RGB Image - Episode {episode_idx}")

# if depth is not None:
#     plot_image(depth, title=f"Depth Image - Episode {episode_idx}", cmap='gray')

# plot_joint_positions(qpos_arm1, title=f"Arm 1 Joint Positions - Episode {episode_idx}")
# plot_joint_positions(camera_pose_qpos, title=f"Camera Pose (Arm 2) Joint Positions - Episode {episode_idx}")

# Cell 5: Summary Statistics (Optional)
def print_summary_stats(file_path):
    """Print summary statistics of the data."""
    with h5py.File(file_path, 'r') as f:
        print(f"File: {file_path}")
        if '/observations/images/rgb' in f:
            rgb = np.array(f['/observations/images/rgb'])
            print(f"RGB Shape: {rgb.shape}, Min: {rgb.min()}, Max: {rgb.max()}")
        if '/observations/images/depth' in f:
            depth = np.array(f['/observations/images/depth'])
            print(f"Depth Shape: {depth.shape}, Min: {depth.min()}, Max: {depth.max()}")
        qpos_arm1 = np.array(f['/observations/qpos'])
        print(f"Arm 1 qpos: {qpos_arm1}, Length: {len(qpos_arm1)}")
        camera_pose_qpos = np.array(f['/camera_pose/qpos'])
        print(f"Camera Pose qpos: {camera_pose_qpos}, Length: {len(camera_pose_qpos)}")

print_summary_stats(file_path)
# Out:
# /home/yilong/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# Added frame from episode_0.h5
# Added frame from episode_1.h5
# Added frame from episode_2.h5
# Added frame from episode_3.h5
# Added frame from episode_4.h5
# Added frame from episode_5.h5
# Added frame from episode_6.h5
# Added frame from episode_7.h5
# Added frame from episode_8.h5
# Added frame from episode_9.h5
# Added frame from episode_10.h5
# Added frame from episode_11.h5
# Added frame from episode_12.h5
# Added frame from episode_13.h5
# Added frame from episode_14.h5
# Added frame from episode_15.h5
# Added frame from episode_16.h5
# Added frame from episode_17.h5
# Added frame from episode_18.h5
# Added frame from episode_19.h5
# Added frame from episode_20.h5
# Added frame from episode_21.h5
# Added frame from episode_22.h5
# Added frame from episode_23.h5
# Added frame from episode_24.h5
# Added frame from episode_25.h5
# Added frame from episode_26.h5
# Added frame from episode_27.h5
# Added frame from episode_28.h5
# Added frame from episode_29.h5
# Added frame from episode_30.h5
# Added frame from episode_31.h5
# Added frame from episode_32.h5
# Added frame from episode_33.h5
# Added frame from episode_34.h5
# Added frame from episode_35.h5
# Added frame from episode_36.h5
# Added frame from episode_37.h5
# Added frame from episode_38.h5
# Added frame from episode_39.h5
# Added frame from episode_40.h5
# Added frame from episode_41.h5
# Added frame from episode_42.h5
# Added frame from episode_43.h5
# Added frame from episode_44.h5
# Added frame from episode_45.h5
# Added frame from episode_46.h5
# Added frame from episode_47.h5
# Added frame from episode_48.h5
# Added frame from episode_49.h5
# Added frame from episode_50.h5
# Added frame from episode_51.h5
# Added frame from episode_52.h5
# Added frame from episode_53.h5
# Added frame from episode_54.h5
# Added frame from episode_55.h5
# Added frame from episode_56.h5
# Added frame from episode_57.h5
# Added frame from episode_58.h5
# Added frame from episode_59.h5
# Added frame from episode_60.h5
# Added frame from episode_61.h5
# Added frame from episode_62.h5
# Added frame from episode_63.h5
# Added frame from episode_64.h5
# Added frame from episode_65.h5
# Added frame from episode_66.h5
# Added frame from episode_67.h5
# Added frame from episode_68.h5
# Added frame from episode_69.h5
# Added frame from episode_70.h5
# Added frame from episode_71.h5
# Added frame from episode_72.h5
# Added frame from episode_73.h5
# Added frame from episode_74.h5
# Added frame from episode_75.h5
# Added frame from episode_76.h5
# Added frame from episode_77.h5
# Added frame from episode_78.h5
# Added frame from episode_79.h5
# Added frame from episode_80.h5
# Added frame from episode_81.h5
# Added frame from episode_82.h5
# Added frame from episode_83.h5
# Added frame from episode_84.h5
# Added frame from episode_85.h5
# Added frame from episode_86.h5
# Added frame from episode_87.h5
# Added frame from episode_88.h5
# Added frame from episode_89.h5
# Added frame from episode_90.h5
# Added frame from episode_91.h5
# Added frame from episode_92.h5
# Added frame from episode_93.h5
# Added frame from episode_94.h5
# Added frame from episode_95.h5
# Added frame from episode_96.h5
# Added frame from episode_97.h5
# Added frame from episode_98.h5
# Added frame from episode_99.h5
# Added frame from episode_100.h5
# Added frame from episode_101.h5
# Added frame from episode_102.h5
# Added frame from episode_103.h5
# Added frame from episode_104.h5
# Added frame from episode_105.h5
# Added frame from episode_106.h5
# Added frame from episode_107.h5
# Added frame from episode_108.h5
# Added frame from episode_109.h5
# Added frame from episode_110.h5
# Added frame from episode_111.h5
# Added frame from episode_112.h5
# Added frame from episode_113.h5
# Added frame from episode_114.h5
# Added frame from episode_115.h5
# Added frame from episode_116.h5
# Added frame from episode_117.h5
# Added frame from episode_118.h5
# Added frame from episode_119.h5
# Added frame from episode_120.h5
# Added frame from episode_121.h5
# Added frame from episode_122.h5
# Added frame from episode_123.h5
# Added frame from episode_124.h5
# Added frame from episode_125.h5
# Added frame from episode_126.h5
# Added frame from episode_127.h5
# Added frame from episode_128.h5
# Added frame from episode_129.h5
# Added frame from episode_130.h5
# Added frame from episode_131.h5
# Added frame from episode_132.h5
# Added frame from episode_133.h5
# Added frame from episode_134.h5
# Added frame from episode_135.h5
# Added frame from episode_136.h5
# Added frame from episode_137.h5
# Added frame from episode_138.h5
# Added frame from episode_139.h5
# Added frame from episode_140.h5
# Added frame from episode_141.h5
# Added frame from episode_142.h5
# Added frame from episode_143.h5
# Added frame from episode_144.h5
# Added frame from episode_145.h5
# Added frame from episode_146.h5
# Added frame from episode_147.h5
# Added frame from episode_148.h5
# Added frame from episode_149.h5
# Added frame from episode_150.h5
# Added frame from episode_151.h5
# Added frame from episode_152.h5
# Added frame from episode_153.h5
# Added frame from episode_154.h5
# Added frame from episode_155.h5
# Added frame from episode_156.h5
# Added frame from episode_157.h5
# Added frame from episode_158.h5
# Added frame from episode_159.h5
# Added frame from episode_160.h5
# Added frame from episode_161.h5
# Added frame from episode_162.h5
# Added frame from episode_163.h5
# Added frame from episode_164.h5
# Added frame from episode_165.h5
# Added frame from episode_166.h5
# Added frame from episode_167.h5
# Added frame from episode_168.h5
# Added frame from episode_169.h5
# Added frame from episode_170.h5
# Added frame from episode_171.h5
# Added frame from episode_172.h5
# Added frame from episode_173.h5
# Added frame from episode_174.h5
# Added frame from episode_175.h5
# Added frame from episode_176.h5
# Added frame from episode_177.h5
# Added frame from episode_178.h5
# Added frame from episode_179.h5
# Added frame from episode_180.h5
# Added frame from episode_181.h5
# Added frame from episode_182.h5
# Added frame from episode_183.h5
# Added frame from episode_184.h5
# Added frame from episode_185.h5
# Added frame from episode_186.h5
# Added frame from episode_187.h5
# Added frame from episode_188.h5
# Added frame from episode_189.h5
# Added frame from episode_190.h5
# Added frame from episode_191.h5
# Added frame from episode_192.h5
# Added frame from episode_193.h5
# Added frame from episode_194.h5
# Added frame from episode_195.h5
# Added frame from episode_196.h5
# Added frame from episode_197.h5
# Added frame from episode_198.h5
# Added frame from episode_199.h5
# Added frame from episode_200.h5
# Added frame from episode_201.h5
# Added frame from episode_202.h5
# Added frame from episode_203.h5
# Added frame from episode_204.h5
# Added frame from episode_205.h5
# Added frame from episode_206.h5
# Added frame from episode_207.h5
# Added frame from episode_208.h5
# Added frame from episode_209.h5
# Added frame from episode_210.h5
# Added frame from episode_211.h5
# Added frame from episode_212.h5
# Added frame from episode_213.h5
# Added frame from episode_214.h5
# Added frame from episode_215.h5
# Added frame from episode_216.h5
# Added frame from episode_217.h5
# Added frame from episode_218.h5
# Added frame from episode_219.h5
# Added frame from episode_220.h5
# Added frame from episode_221.h5
# Added frame from episode_222.h5
# Added frame from episode_223.h5
# Added frame from episode_224.h5
# Added frame from episode_225.h5
# Added frame from episode_226.h5
# Added frame from episode_227.h5
# Added frame from episode_228.h5
# Added frame from episode_229.h5
# Added frame from episode_230.h5
# Added frame from episode_231.h5
# Added frame from episode_232.h5
# Added frame from episode_233.h5
# Added frame from episode_234.h5
# Added frame from episode_235.h5
# Added frame from episode_236.h5
# Added frame from episode_237.h5
# Added frame from episode_238.h5
# Added frame from episode_239.h5
# Added frame from episode_240.h5
# Added frame from episode_241.h5
# Added frame from episode_242.h5
# Added frame from episode_243.h5
# Added frame from episode_244.h5
# Added frame from episode_245.h5
# Added frame from episode_246.h5
# Added frame from episode_247.h5
# Added frame from episode_248.h5
# Added frame from episode_249.h5
# Added frame from episode_250.h5
# Added frame from episode_251.h5
# Added frame from episode_252.h5
# Added frame from episode_253.h5
# Added frame from episode_254.h5
# Added frame from episode_255.h5
# Added frame from episode_256.h5
# Added frame from episode_257.h5
# Added frame from episode_258.h5
# Added frame from episode_259.h5
# Added frame from episode_260.h5
# Added frame from episode_261.h5
# Added frame from episode_262.h5
# Added frame from episode_263.h5
# Added frame from episode_264.h5
# Added frame from episode_265.h5
# Added frame from episode_266.h5
# Added frame from episode_267.h5
# Added frame from episode_268.h5
# Added frame from episode_269.h5
# Added frame from episode_270.h5
# Added frame from episode_271.h5
# Added frame from episode_272.h5
# Added frame from episode_273.h5
# Added frame from episode_274.h5
# Added frame from episode_275.h5
# Added frame from episode_276.h5
# Added frame from episode_277.h5
# Added frame from episode_278.h5
# Added frame from episode_279.h5
# Added frame from episode_280.h5
# Added frame from episode_281.h5
# Added frame from episode_282.h5
# Added frame from episode_283.h5
# Added frame from episode_284.h5
# Added frame from episode_285.h5
# Added frame from episode_286.h5
# Added frame from episode_287.h5
# Added frame from episode_288.h5
# Added frame from episode_289.h5
# Added frame from episode_290.h5
# Added frame from episode_291.h5
# Added frame from episode_292.h5
# Added frame from episode_293.h5
# Added frame from episode_294.h5
# Added frame from episode_295.h5
# Added frame from episode_296.h5
# Added frame from episode_297.h5
# Added frame from episode_298.h5
# Added frame from episode_299.h5
# Added frame from episode_300.h5
# Added frame from episode_301.h5
# Added frame from episode_302.h5
# Added frame from episode_303.h5
# Added frame from episode_304.h5
# Added frame from episode_305.h5
# Added frame from episode_306.h5
# Added frame from episode_307.h5
# Added frame from episode_308.h5
# Added frame from episode_309.h5
# Added frame from episode_310.h5
# Added frame from episode_311.h5
# Added frame from episode_312.h5
# Added frame from episode_313.h5
# Added frame from episode_314.h5
# Added frame from episode_315.h5
# Added frame from episode_316.h5
# Added frame from episode_317.h5
# Added frame from episode_318.h5
# Added frame from episode_319.h5
# Added frame from episode_320.h5
# Added frame from episode_321.h5
# Added frame from episode_322.h5
# Added frame from episode_323.h5
# Added frame from episode_324.h5
# Added frame from episode_325.h5
# Added frame from episode_326.h5
# Added frame from episode_327.h5
# Added frame from episode_328.h5
# Added frame from episode_329.h5
# Added frame from episode_330.h5
# Added frame from episode_331.h5
# Added frame from episode_332.h5
# Added frame from episode_333.h5
# Added frame from episode_334.h5
# Added frame from episode_335.h5
# Added frame from episode_336.h5
# Added frame from episode_337.h5
# Added frame from episode_338.h5
# Added frame from episode_339.h5
# Added frame from episode_340.h5
# Added frame from episode_341.h5
# Added frame from episode_342.h5
# Added frame from episode_343.h5
# Added frame from episode_344.h5
# Added frame from episode_345.h5
# Added frame from episode_346.h5
# Added frame from episode_347.h5
# Added frame from episode_348.h5
# Added frame from episode_349.h5
# Added frame from episode_350.h5
# Added frame from episode_351.h5
# Added frame from episode_352.h5
# Added frame from episode_353.h5
# Added frame from episode_354.h5
# Added frame from episode_355.h5
# Added frame from episode_356.h5
# Added frame from episode_357.h5
# Added frame from episode_358.h5
# Added frame from episode_359.h5
# Added frame from episode_360.h5
# Added frame from episode_361.h5
# Added frame from episode_362.h5
# Added frame from episode_363.h5
# Added frame from episode_364.h5
# Added frame from episode_365.h5
# Added frame from episode_366.h5
# Added frame from episode_367.h5
# Added frame from episode_368.h5
# Added frame from episode_369.h5
# Added frame from episode_370.h5
# Added frame from episode_371.h5
# Added frame from episode_372.h5
# Added frame from episode_373.h5
# Added frame from episode_374.h5
# Added frame from episode_375.h5
# Added frame from episode_376.h5
# Added frame from episode_377.h5
# Added frame from episode_378.h5
# Added frame from episode_379.h5
# Added frame from episode_380.h5
# Added frame from episode_381.h5
# Added frame from episode_382.h5
# Added frame from episode_383.h5
# Added frame from episode_384.h5
# Added frame from episode_385.h5
# Added frame from episode_386.h5
# Added frame from episode_387.h5
# Added frame from episode_388.h5
# Added frame from episode_389.h5
# Added frame from episode_390.h5
# Added frame from episode_391.h5
# Added frame from episode_392.h5
# Added frame from episode_393.h5
# Added frame from episode_394.h5
# Added frame from episode_395.h5
# Added frame from episode_396.h5
# Added frame from episode_397.h5
# Added frame from episode_398.h5
# Added frame from episode_399.h5
# Added frame from episode_400.h5
# Added frame from episode_401.h5
# Added frame from episode_402.h5
# Added frame from episode_403.h5
# Added frame from episode_404.h5
# Added frame from episode_405.h5
# Added frame from episode_406.h5
# Added frame from episode_407.h5
# Added frame from episode_408.h5
# Added frame from episode_409.h5
# Added frame from episode_410.h5
# Added frame from episode_411.h5
# Added frame from episode_412.h5
# Video saved as datasets/20250324_203250/rgb_video.mp4
# File: datasets/20250324_203250/episode_0.h5
# RGB Shape: (480, 848, 3), Min: 0, Max: 222
# Depth Shape: (480, 848), Min: 0.0, Max: 849.0
# Arm 1 qpos: [-0.05522331 -1.93434978  1.63829148  0.13345633  0.64887387  0.02454369
#   1.32075751  0.05690189 -0.05690189], Length: 9
# Camera Pose qpos: [ 0.2239612   0.60285449 -0.16873789 -1.05998075  1.05998075  1.69811678
#   0.00306796  0.02856319 -0.02856319], Length: 9

# %%
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
import os
from IPython.display import Video

import matplotlib.pyplot as plt
rgb, depth, qpos_arm1, camera_pose_qpos = load_episode(file_path)

rgb = rgb.reshape([-1, 480, 848, 3])
# Create a figure and axis for the animation
fig, ax = plt.subplots()
im = ax.imshow(rgb[0])  # Display the first frame initially
ax.axis('off')  # Turn off the axis

# Update function for the animation
def update(frame):
    im.set_array(rgb[frame])
    return [im]

# Create the animation
ani = FuncAnimation(fig, update, frames=len(rgb), interval=50, blit=True)

# Save the animation as an MP4 file
output_file = "output_video.mp4"
ani.save(output_file, writer="ffmpeg", fps=10)

# Close the figure to avoid displaying it twice
plt.close(fig)

# Display the video in the notebook
Video(output_file, embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
from PIL import Image

# Image.fromarray(rgb[0]).save("tasks/mug/ref_rgb.png")
# Image.fromarray(depth[0]).save("tasks/mug/ref_depth.png")
np.save("tasks/mug/ref_depth.npy", depth[0])

# %%
create_rgb_video

# %%
# Cell 6: Visualize Joint Position Changes Over Episodes
def plot_joint_changes(dataset_dir, folder_name):
    """Plot changes in joint positions for arm_1 and arm_2 across all episodes."""
    episode_files = sorted([f for f in os.listdir(os.path.join(dataset_dir, folder_name)) 
                           if f.endswith('.h5')], key=lambda x: int(x.split('_')[1].split('.')[0]))
    
    if not episode_files:
        print("No HDF5 files found in the specified folder.")
        return
    
    # Initialize lists to store joint data
    arm1_qpos_history = []
    arm2_qpos_history = []
    episode_nums = []
    
    # Load joint positions from each episode
    for episode_file in episode_files:
        file_path = os.path.join(dataset_dir, folder_name, episode_file)
        _, _, qpos_arm1, camera_pose_qpos = load_episode(file_path)
        print(qpos_arm1)
        arm1_qpos_history.append(qpos_arm1)
        arm2_qpos_history.append(camera_pose_qpos)
        episode_nums.append(int(episode_file.split('_')[1].split('.')[0]))
    
    # Convert to numpy arrays for easier manipulation
    arm1_qpos_history = np.array(arm1_qpos_history)  # Shape: (n_episodes, n_joints_arm1)
    arm2_qpos_history = np.array(arm2_qpos_history)  # Shape: (n_episodes, n_joints_arm2)
    
    # Plot arm_1 joint changes
    plt.figure(figsize=(12, 6))
    for joint_idx in range(arm1_qpos_history.shape[1]):
        plt.plot(episode_nums, arm1_qpos_history[:, joint_idx], marker='o', linestyle='-', 
                 label=f'Joint {joint_idx}')
    plt.title("Arm 1 Joint Position Changes Over Episodes")
    plt.xlabel("Episode Number")
    plt.ylabel("Joint Position (rad)")
    plt.legend(loc='best')
    plt.grid(True)
    plt.show()
    
    # Plot arm_2 (camera pose) joint changes
    plt.figure(figsize=(12, 6))
    for joint_idx in range(arm2_qpos_history.shape[1]):
        plt.plot(episode_nums, arm2_qpos_history[:, joint_idx], marker='o', linestyle='-', 
                 label=f'Joint {joint_idx}')
    plt.title("Arm 2 (Camera Pose) Joint Position Changes Over Episodes")
    plt.xlabel("Episode Number")
    plt.ylabel("Joint Position (rad)")
    plt.legend(loc='best')
    plt.grid(True)
    plt.show()

# Specify dataset directory and folder name (same as previous cells)
dataset_dir = "datasets"
folder_name = "20250324_204534"  # Replace with your timestamp

# Plot joint changes
plot_joint_changes(dataset_dir, folder_name)

# %%
import os
import h5py
import numpy as np
from pathlib import Path

# Define the base directory containing your datasets
base_dir = Path("~/ObAct_realworld/datasets").expanduser()

# Function to merge .h5 files from a folder into a single .h5 file
def merge_h5_files(folder_path, output_file):
    # List all .h5 files in the folder
    h5_files = sorted([f for f in os.listdir(folder_path) if f.endswith(".h5")])
    if not h5_files:
        print(f"No .h5 files found in {folder_path}")
        return

    # Open the output .h5 file in write mode
    with h5py.File(output_file, "w") as out_f:
        # Track the datasets to concatenate
        data_dict = {}

        # Iterate through each .h5 file (episode)
        for h5_file in h5_files:
            input_file = folder_path / h5_file
            with h5py.File(input_file, "r") as in_f:
                # Recursively copy and concatenate datasets
                def collect_datasets(name, obj):
                    if isinstance(obj, h5py.Dataset):
                        if name not in data_dict:
                            data_dict[name] = []
                        # print(obj[()].shape)
                        data_dict[name].append(obj[()])  # Get the data as a NumPy array

                in_f.visititems(collect_datasets)

        # Write concatenated datasets to the output file
        for name, data_list in data_dict.items():
            # print(len(data_list))
            # # Concatenate along the first axis (assuming episodes are stacked this way)
            concatenated_data = np.stack(data_list)
            # print(concatenated_data.shape)
            out_f.create_dataset(name, data=concatenated_data)
    print(f"Created {output_file} with data from {len(h5_files)} episodes.")

# Process each folder in the dataset directory
for folder in sorted(base_dir.iterdir()):
    if folder.is_dir():
        output_file = base_dir / f"{folder.name}_v2.h5"
        if output_file.exists():
            print(f"Skipping {output_file} as it already exists.")
            continue
        print(f"Processing {folder.name}...")
        merge_h5_files(folder, output_file)

print("Merging complete!")
